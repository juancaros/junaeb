# %% [markdown]
# ### housekeeping

# %%
import numpy as np
import seaborn as sns
import pandas as pd
import json
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
cned = pd.read_csv('data/cned/cned.csv')
sned = pd.read_csv('data/sned/sned.csv')
mn = pd.read_csv('data/mn/1m2017.csv')
geoData = pd.read_csv('data/geo/geo_rbd.csv')
# sim1 = pd.read_csv('data/mn/1b2015.csv')
cned.dropna(inplace=True)
sned.dropna(inplace=True)
# sim1.dropna(inplace=True)
mn.dropna(inplace=True)
# geoData.dropna(inplace=True)

# %% [markdown]
# # Human capital skills for jobs in the next generation
#
#     Increasingly, highly demanded jobs require a diverse set of human capital skills: team-building, mindfulness, continous learning (see an example from [United Nations](https://careers.un.org/lbw/attachments/competencies_booklet_en.pdf)). Moreover, jobs in demand are linked to fast growing higher education programs, which in turn have stricter entry requirements, measured by standarized tests (like SAT or equivalent).
#
#
#     Here is an example from Chile, showing the relationship between mean standarized college entry scores in Chile (PSU) and enrollement size for each program across all areas of higher education between 2006 and 2019 (excludes programs without test requirements). Programs with larger enrollment also have higher admision standards, particularly for STEM, Business and Law.

# %%
# change plot size
cned.rename(columns={"puntaje": "score", "ingreso2": "enrollment"}, inplace=True)
scatter1 = sns.pairplot(x_vars="score", y_vars="enrollment", data=cned, hue="area", height=4)

# %% [markdown]
# This complex mix of capacities, required to be successful in atractive career paths, demand an active human skill accumulation process during the school years. Extensive evidence indicates that active learning at school requires a mix of socio-emotional skills and physical health. The [OCDE](https://read.oecd-ilibrary.org/social-issues-migration-health/the-heavy-burden-of-obesity_67450d67-en#page1) estimates suggest that normal weight children are 13% more likely to perform well at school, relative to their less healthy peers. Moreover, both physical health and socio-emotional skills are intimately connected. [Research](https://www.journals.uchicago.edu/doi/abs/10.1086/692016?journalCode=jhc) shows that obese children tend to accumulate less socio-emotional skills over time.
#
# Again, an example from Chile can be informative. Here is a binned plot showing the obesity prevalence at high school level by average school learning performace in 2015-2017 for voucher schools (each observation in the data is a school). School performance is measured by the average standarized scores (0-100) across all disciplines (e.g. math, languague) and school levels (primary, middle, high). Overall, voucher schools with high effectiveness (i.e. higher average learning) also have a lower proportion of obese students.

# %%
mn['obesityPrevalence'] = ((mn['onino'] + mn['onina']) / mn['total']) * 100
mn.set_index('idrbd')
mn['idrbd'] = mn['idrbd'].astype(np.int64)
sned.rename(columns={"efectivr": "schoolPerformance"}, inplace=True)
mergedData = pd.merge(mn, sned, on='idrbd', how='inner')

#scatterplot
#plt.scatter(mergedData['schoolPerformance'], mergedData['obesityPrevalence'])

#binned scatterplot
bin1 = sns.regplot('schoolPerformance', 'obesityPrevalence', 
            data=mergedData, x_bins=30, ci=None, fit_reg=False)

bin1.savefig("bin1.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9df69c5d3f33> in <module>
#      12             data=mergedData, x_bins=30, ci=None, fit_reg=False)
#      13
# ---> 14 bin1.savefig("bin1.png")
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %% [markdown]
# We face a vicious cycle: stressful environments favor weight gain among children, which in turn affects their socio-emotional development, making them less likely to adopt healthy behaviors.

# %% [markdown]
# # Monitoring early human capital skills
#
# Given the importance of early human capital accumulation from a life-cycle perspective, we would want to track and support disadvantage groups once they enter the school system. Fortunately, there are several ways to collect information once children are at school. For example, in many countries the School Meal Programs provide an unique opportunity to collect health and socio-economic information of each student.

# %% [markdown]
# Our solution is founded on exploiting the potential of such routine administrative data at the PK-12 ages. For example, data is periodically collected for all students in specific grades attending public and voucher schools in Chile.
#
# Our toolkit is based on a simple human capital framework that formalize the statistical assumptions needed for a country-wide model that allows to predict the future path for children's human capital accumulation, based on the longitudinal data available from multiple cohorts. Our solution not only can forecast future risks at the local level (e.g. district), but also allow to predict and evaluate the impact of interventions. The toolkit is based on a combination of theoretical premises as well as statistical foundations, using simple Python tools.
#
# Below there are a few simple examples of functionality based on simulated data from Chile, representing 10% of total enrollment in 1st grade of primary school.

# %%
#visualization

# %%
#factor analysis

# %%
#statistical manipulation

# %%
#geodata visualization
geoData.duplicated().value_counts()
# Out:
# False    16024
# dtype: int64

# %%
mn['idrbd'].duplicated().value_counts()
# Out:
# False    2480
# Name: idrbd, dtype: int64

# %%
mergedGeo = pd.merge(mn, geoData, on='idrbd', how='outer')

# %%
mergedGeo[['idrbd', 'LATITUD']].isna()['LATITUD'].value_counts()
# Out:
# False    12536
# True      3488
# Name: LATITUD, dtype: int64

# %%
mn['idrbd']
# Out:
# 0          97.0
# 1         103.0
# 2         106.0
# 3         107.0
# 4         108.0
#          ...
# 2475    30001.0
# 2476    30003.0
# 2477    40230.0
# 2478       72.0
# 2479       78.0
# Name: idrbd, Length: 2480, dtype: float64

# %%
geoData.columns
# Out:
# Index(['year', 'idrbd', 'DGV_RBD', 'NOM_RBD', 'MRUN', 'RUT_SOSTENEDOR',
#        'P_JURIDICA', 'COD_REG_RBD', 'COD_PRO_RBD', 'COD_COM_RBD',
#        'NOM_COM_RBD', 'COD_DEPROV_RBD', 'NOM_DEPROV_RBD', 'COD_DEPE',
#        'COD_DEPE2', 'RURAL_RBD', 'LATITUD', 'LONGITUD', 'CONVENIO_PIE',
#        'ENS_01', 'ENS_02', 'ENS_03', 'ENS_04', 'ENS_05', 'ENS_06', 'ENS_07',
#        'ENS_08', 'ENS_09', 'MATRICULA', 'ESTADO_ESTAB', 'ORI_RELIGIOSA',
#        'ORI_OTRO_GLOSA', 'PAGO_MATRICULA', 'PAGO_MENSUAL'],
#       dtype='object')

# %%
mergedGeo['idrbd'].duplicated().value_counts()
mergedGeoSubset = mergedGeo[['idrbd', 'LATITUD', 'LONGITUD', 'NOM_RBD', 'NOM_COM_RBD', 'NOM_DEPROV_RBD']]

# %%
mergedGeoSubset.dropna(inplace=True)
mergedGeoSubset.reset_index(drop=True, inplace=True)
# Out:
# /home/alberto/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mergedGeoSubset['LONGITUD'][5004]
# Out:
# '-70,58'

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

# %%
geojson = {
    "type": 'FeatureCollection',
}
features = []
i = 0

while i < len(mergedGeoSubset):
#     print(mergedGeo['LATITUD'][i])
#     if mergedGeo['LATITUD'][i] != -9 and mergedGeo['LONGITUD'][i] != -9:
    featureObject = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [mergedGeoSubset['LONGITUD'][i][:3] + '.' + mergedGeoSubset['LONGITUD'][i][3:] , mergedGeoSubset['LATITUD'][i][:3]+ '.' + mergedGeoSubset['LATITUD'][i][3:]]
        },
        "properties": {
            "schoolName": mergedGeoSubset['NOM_RBD'][i],
            "community": mergedGeoSubset['NOM_COM_RBD'][i],
            "province": mergedGeoSubset['NOM_DEPROV_RBD'][i]
        }
    }
    features.append(featureObject)
    i=i+1
    
geojson['features'] = features

# %%
geojson
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15323392', '-20.21983585']},
#    'properties': {'schoolName': 'INST. COM. DE IQUIQUE BALDOMERO WOLNITZKY',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13817004', '-20.22109594']},
#    'properties': {'schoolName': 'ESC.EDUC.GRAL.BAS.Y DES.ART.VIOLETA PARRA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.12724452', '-20.29401349']},
#    'properties': {'schoolName': 'INSTITUTO DEL MAR ALMIRANTE CARLOS CONDEL',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15238682', '-20.21974441']},
#    'properties': {'schoolName': 'LICEO LIBERT. GRAL.BERNARDO O�HIGGINS',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14872946', '-20.22579486']},
#    'properties': {'schoolName': 'LICEO POLITEC. JOSE GUTIERREZ DE LA FUEN',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15337963', '-20.21695112']},
#    'properties': {'schoolName': 'LICEO ELENA DUVAUCHELLE CABEZON',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13544477', '-20.22471195']},
#    'properties': {'schoolName': 'LICEO BICENTENARIO DOMINGO SANTA MARIA DE IQQ.',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.1374329', '-20.2419955']},
#    'properties': {'schoolName': 'LICEO LUIS CRUZ MARTINEZ',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13812103', '-20.24541641']},
#    'properties': {'schoolName': 'ESCUELA PROFESOR MANUEL CASTRO RAMOS',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14838116', '-20.22232531']},
#    'properties': {'schoolName': 'LICEO MARIA AUXILIADORA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15143279', '-20.2210866']},
#    'properties': {'schoolName': 'LICEO SUPERIOR GABRIELA MISTRAL',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14422847', '-20.22346373']},
#    'properties': {'schoolName': 'COLEGIO NORTH COLLEGE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14818092', '-20.22463663']},
#    'properties': {'schoolName': 'LICEO PARTICULAR MIXTO ESCASCE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13943264', '-20.33293869']},
#    'properties': {'schoolName': 'LICEO ACADEMIA IQUIQUE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14849999', '-20.22514112']},
#    'properties': {'schoolName': 'COLEGIO ADVENTISTA DE IQUIQUE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15438513', '-20.21558387']},
#    'properties': {'schoolName': 'LICEO ATENEA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14311631', '-20.22387684']},
#    'properties': {'schoolName': 'COLEGIO IQUIQUE YOUNG SCHOOL',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14571502', '-20.21050991']},
#    'properties': {'schoolName': 'COLEGIO SAN MARTIN',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13876586', '-20.21493215']},
#    'properties': {'schoolName': 'COLEGIO LITTLE COLLEGE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14101057', '-20.22408138']},
#    'properties': {'schoolName': 'LICEO PDTE. ANIBAL PINTO GARMENDIA.',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15232513', '-20.21907508']},
#    'properties': {'schoolName': 'COLEGIO NUSTA KORI',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14553168', '-20.20908793']},
#    'properties': {'schoolName': 'COLEGIO DIOCESANO OBISPO LABBE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13704046', '-20.2490679']},
#    'properties': {'schoolName': 'COLEGIO MARIA REINA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13903899', '-20.22128941']},
#    'properties': {'schoolName': 'COLEGIO HISPANO ITALIANA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.12402135', '-20.27096026']},
#    'properties': {'schoolName': 'LICEO SAMCA ARUMANTI',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.12406394', '-20.26714415']},
#    'properties': {'schoolName': 'COLEGIO ANTAMARA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14514322', '-20.21823326']},
#    'properties': {'schoolName': 'ESCUELA BASICA CORONA SCHOOL',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15147588', '-20.2228522']},
#    'properties': {'schoolName': 'COLEGIO INGLES',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13018941', '-20.24990194']},
#    'properties': {'schoolName': 'COLEGIO HUMBERSTONE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.12569262', '-20.26514233']},
#    'properties': {'schoolName': 'COLEGIO HISPANO BRITANICO IQUIQUE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.14997179', '-20.22387771']},
#    'properties': {'schoolName': 'COLEGIO SALESIANO DE IQUIQUE',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.13359363', '-20.24316365']},
#    'properties': {'schoolName': 'LICEO COLEGIO DEPORTIVO',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.15102208', '-20.21726561']},
#    'properties': {'schoolName': 'COLEGIO UNIVERSITARIO UNAP',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.12249554', '-20.26676685']},
#    'properties': {'schoolName': 'COLEGIO LATIONOAMERICANO  LAS PARINAS',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-70.12092', '-20.290195']},
#    'properties': {'schoolName': 'IQRA ARABIAN BRITISH SCHOOL',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-70.12672', '-20.265045']},
#    'properties': {'schoolName': 'COLEGIO MAHATMA GANDHI',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-70.146286', '-20.220598']},
#    'properties': {'schoolName': 'COLEGIO ACADEMIA TARAPACA ORELLA',
#     'community': 'IQUIQUE',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.09438285', '-20.27140827']},
#    'properties': {'schoolName': 'LICEO S.S JUAN PABLO SEGUNDO',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.09941539', '-20.26131127']},
#    'properties': {'schoolName': 'LICEO COLEGIO METODISTA ROBERT JOHNSON',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.10439866', '-20.26780247']},
#    'properties': {'schoolName': 'COLEGIO METODISTA WILLIAM TAYLOR',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.10601271', '-20.25467447']},
#    'properties': {'schoolName': 'ESC. BASICA Y PARV. KRONOS SCHOOL',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.10700667', '-20.25557647']},
#    'properties': {'schoolName': 'LICEO LOS CONDORES',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.10415821', '-20.2590478']},
#    'properties': {'schoolName': 'ACADEMIA HOSPICIO',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.09833182', '-20.28336103']},
#    'properties': {'schoolName': 'COLEGIO SIMON BOLIVAR',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.09683285', '-20.27479487']},
#    'properties': {'schoolName': 'LICEO SUPERIOR DIEGO PORTALES',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.09834024', '-20.27998496']},
#    'properties': {'schoolName': 'COLEGIO SAGRADO CORAZON DE JESUS',
#     'community': 'ALTO HOSPICIO',
#     'province': 'IQUIQUE'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70
',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.44066808', '-23.10523208']},
#    'properties': {'schoolName': 'COMPLEJO EDUCATIVO JUAN JOSE LATORRE BENAVENT',
#     'community': 'MEJILLONES',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-69.32028742', '-22.89083475']},
#    'properties': {'schoolName': 'ESCUELA CARACOLES',
#     'community': 'SIERRA GORDA',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.47446422', '-25.40233792']},
#    'properties': {'schoolName': 'LICEO POLITECNICO JOSE MIGUEL QUIROZ',
#     'community': 'TALTAL',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.48472797', '-25.40683021']},
#    'properties': {'schoolName': 'LICEO JUAN CORTES-MONROY CORTES',
#     'community': 'TALTAL',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92665417', '-22.45509731']},
#    'properties': {'schoolName': 'LICEO LUIS CRUZ MARTINEZ',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.93124368', '-22.45825664']},
#    'properties': {'schoolName': 'LICEO FRANCISCO DE AGUIRRE',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92049243', '-22.45876195']},
#    'properties': {'schoolName': 'LICEO POLITECNICO CESAREO AGUIRRE G.',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92419894', '-22.43793055']},
#    'properties': {'schoolName': 'LICEO MINERO AM�RICA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92668752', '-22.4657191']},
#    'properties': {'schoolName': 'COLEGIO ADVENTISTA DE CALAMA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.9277117', '-22.46183422']},
#    'properties': {'schoolName': 'FUNDACION EDUC.COLEGIO NUESTRA SRA.DE AYQUINA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.93066766', '-22.45990004']},
#    'properties': {'schoolName': 'COLEGIO  EJERCITO DE SALVACION',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92652932', '-22.46956796']},
#    'properties': {'schoolName': 'INSTITUTO OBISPO SILVA LEZAETA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.9235225', '-22.44695133']},
#    'properties': {'schoolName': 'COLEGIO JUAN PABLO II',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92457317', '-22.4584199']},
#    'properties': {'schoolName': 'LICEO ELEUTERIO RAMIREZ MOLINA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92811078', '-22.4462778']},
#    'properties': {'schoolName': 'LICEO JORGE ALESSANDRI RODRIGUEZ',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92904662', '-22.44391734']},
#    'properties': {'schoolName': 'COLEGIO CALAMA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.94800235', '-22.45374056']},
#    'properties': {'schoolName': 'COLEGIO RIO LOA',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.93727288', '-22.4723183']},
#    'properties': {'schoolName': 'COLEGIO ECOLOGICO MONTESSORI',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.93291763', '-22.46827348']},
#    'properties': {'schoolName': 'COLEGIO PADRE ALBERTO HURTADO',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.91226644', '-22.4378052']},
#    'properties': {'schoolName': 'COLEGIO PARTICULAR SAN NICOLAS',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92732395', '-22.44894644']},
#    'properties': {'schoolName': 'LICEO RADOMIRO TOMIC ROMERO',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.92937895', '-22.47015858']},
#    'properties': {'schoolName': 'LICEO BICENTENARIO DIEGO PORTALES PALAZUELOS',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-68.93084', '-22.458693']},
#    'properties': {'schoolName': 'AULA HOSPITALARIA SAN CARLOS',
#     'community': 'CALAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.00642913', '-23.19017015']},
#    'properties': {'schoolName': 'COMPLEJO EDUCACIONAL TOCONAO',
#     'community': 'SAN PEDRO DE ATACAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-68.21590104', '-22.93134443']},
#    'properties': {'schoolName': 'LICEO AGROPECUARIO LIKAN ANTAI',
#     'community': 'SAN PEDRO DE ATACAMA',
#     'province': 'EL LOA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.19479052', '-22.08858102']},
#    'properties': {'schoolName': 'LICEO DOMINGO LATRILLE LASTAUNOU',
#     'community': 'TOCOPILLA',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.19428429', '-21.8997286']},
#    'properties': {'schoolName': 'LICEO POLITECNICO DIEGO PORTALES P.',
#     'community': 'TOCOPILLA',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.20499644', '-22.09458189']},
#    'properties': {'schoolName': 'COLEGIO SAGRADA FAMILIA',
#     'community': 'TOCOPILLA',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-69.66711836', '-22.34669407']},
#    'properties': {'schoolName': 'LICEO  H.C. T.P.  MARIA ELENA',
#     'community': 'MARIA ELENA',
#     'province': 'ANTOFAGASTA - TOCOPILLA'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.33441711', '-27.36406545']},
#    'properties': {'schoolName': 'INSTITUTO COMERCIAL ALEJANDRO RIVERA DIAZ',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32821999', '-27.37435103']},
#    'properties': {'schoolName': 'LICEO JOSE ANTONIO CARVAJAL',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32537098', '-27.36962147']},
#    'properties': {'schoolName': 'LICEO MERCEDES FRITIS MACKENNEY',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32836337', '-27.37387785']},
#    'properties': {'schoolName': 'LICEO DE MUSICA',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.33645976', '-27.36608273']},
#    'properties': {'schoolName': 'LICEO CATOLICO ATACAMA',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.33335414', '-27.3615069']},
#    'properties': {'schoolName': 'LICEO POLITECNICO BELEN',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.33795101', '-27.36657742']},
#    'properties': {'schoolName': 'LICEO SAGRADO CORAZON',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32711398', '-27.36986869']},
#    'properties': {'schoolName': 'COLEGIO ADVENTISTA DE COPIAPO',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.34548043', '-27.36264767']},
#    'properties': {'schoolName': 'ESCUELA TECNICO PROFESIONAL',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.30744774', '-27.38619866']},
#    'properties': {'schoolName': 'COLEGIO SAN AGUSTIN DE ATACAMA',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.31767321', '-27.36980118']},
#    'properties': {'schoolName': 'LICEO TECNOLOGICO DE COPIAPO',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.33707508', '-27.36706808']},
#    'properties': {'schoolName': 'ESC.INDUSTRIAL SALESIANA CRISTO REDENTOR',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32641942', '-27.36496374']},
#    'properties': {'schoolName': 'LICEO TECNICO PROFESIONAL HEROES DE ATACAMA',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32924353', '-27.38285472']},
#    'properties': {'schoolName': 'LICEO EL PALOMAR',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.32139514', '-27.37203936']},
#    'properties': {'schoolName': 'ESC.ESP.HOSPITALARIA HOSPITAL SAN JOSE DEL C',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.31145545', '-27.38859498']},
#    'properties': {'schoolName': 'COLEGIO CERVANTINO',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.30504531', '-27.38709045']},
#    'properties': {'schoolName': 'COLEGIO SAN FRANCISCO DE LA SELVA',
#     'community': 'COPIAPO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.82684806', '-27.07361929']},
#    'properties': {'schoolName': 'LICEO MANUEL BLANCO ENCALADA',
#     'community': 'CALDERA',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.80894805', '-27.06588093']},
#    'properties': {'schoolName': 'COLEGIO PARROQUIAL PADRE NEGRO',
#     'community': 'CALDERA',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.82149272', '-27.06523999']},
#    'properties': {'schoolName': 'COLEGIO PARTICULAR CALDERA',
#     'community': 'CALDERA',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.25320514', '-27.47769509']},
#    'properties': {'schoolName': 'ESCUELA DE CONCENTRACION',
#     'community': 'TIERRA AMARILLA',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.26551869', '-27.48335133']},
#    'properties': {'schoolName': 'LICEO JORGE ALESSANDRI RODRIGUEZ',
#     'community': 'TIERRA AMARILLA',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.61751209', '-26.34414753']},
#    'properties': {'schoolName': 'LICEO FEDERICO VARELA',
#     'community': 'CHA�ARAL',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.61732545', '-26.34621032']},
#    'properties': {'schoolName': 'COLEGIO HISPANO AMERICA',
#     'community': 'CHA�ARAL',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.05819028', '-26.3900745']},
#    'properties': {'schoolName': 'LICEO MANUEL MAGALHAES MEDLING',
#     'community': 'DIEGO DE ALMAGRO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-69.62873497', '-26.24687937']},
#    'properties': {'schoolName': 'LICEO DIEGO DE ALMEIDA',
#     'community': 'DIEGO DE ALMAGRO',
#     'province': 'COPIAPO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.75794776', '-28.57632893']},
#    'properties': {'schoolName': 'LICEO PEDRO TRONCOSO MACHUCA',
#     'community': 'VALLENAR',
#     'province': 'HUASCO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.75224781', '-28.58086111']},
#    'properties': {'schoolName': 'LICEO JOSE SANTOS OSSA',
#     'community': 'VALLENAR',
#     'province': 'HUASCO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.75547611', '-28.57674836']},
#    'properties': {'schoolName': 'LICEO SANTA MARTA',
#     'community': 'VALLENAR',
#     'province': 'HUASCO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.7664387', '-28.57443847']},
#    'properties': {'schoolName': 'LICEO SAN FRANCISCO',
#     'community': 'VALLENAR',
#     'province': 'HUASCO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-70.76655966', '-28.58775114']},
#    'properties': {'schoolName': 'LICEO POLITECNICO',
#     'community': 'VALLENAR',
#     'province': 'HUASCO'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': 

#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.05997923', '-36.79900712']},
#    'properties': {'schoolName': 'COLEGIO PADRE LUIS AMIGO',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.07082848', '-36.82446678']},
#    'properties': {'schoolName': 'COLEGIO ALERCE',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-73.029924', '-36.803779']},
#    'properties': {'schoolName': 'LICEO TECNICO PROFESIONAL LA ARAUCANA',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.06218003', '-36.79974972']},
#    'properties': {'schoolName': 'COLEGIO INGL�S BRITISH ROYAL SCHOOL',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.04504445', '-36.81092433']},
#    'properties': {'schoolName': 'COL. TECNICO PROFESIONAL LOS ACACIOS',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.03440768', '-36.81904928']},
#    'properties': {'schoolName': 'COLEGIO SALESIANO DE CONCEPCION',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.04868197', '-36.8280106']},
#    'properties': {'schoolName': 'COLEGIO INMACULADA CONCEPCION',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.05019584', '-36.82306023']},
#    'properties': {'schoolName': 'COLEGIO METODISTA CONCEPCION',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.01930679', '-36.82171582']},
#    'properties': {'schoolName': 'COLEGIO CREACI�N CONCEPCI�N',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.05739906', '-36.82831754']},
#    'properties': {'schoolName': 'COLEGIO CARMELA ROMERO DE ESPINOSA',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.06189738', '-36.83362794']},
#    'properties': {'schoolName': 'COLEGIO ALMONDALE LOMAS',
#     'community': 'CONCEPCION',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.17768593', '-37.02623209']},
#    'properties': {'schoolName': 'LICEO INDUSTRIAL FUNDACI�N FEDERICO SCHWAGER',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.1559559', '-37.01176417']},
#    'properties': {'schoolName': 'LICEO COMERCIAL ANDRES BELLO LOPEZ',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.14682623', '-37.0282125']},
#    'properties': {'schoolName': 'LICEO CORONEL ANTONIO SALAMANCA',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15313483', '-37.00771715']},
#    'properties': {'schoolName': 'LICEO YOBILO DE CORONEL',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16558453', '-37.00228293']},
#    'properties': {'schoolName': 'ESCUELA ROSITA RENARD',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.52865432', '-36.97569053']},
#    'properties': {'schoolName': 'ESCUELA JUAN JOSE LATORRE BENAVENTE',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.1683622', '-36.99169191']},
#    'properties': {'schoolName': 'LICEO INDUSTRIAL METODISTA DE CORONEL',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16753516', '-36.98192323']},
#    'properties': {'schoolName': 'INSTITUTO DE HUMANIDADES ANTONIO MORENO CASAMITJANA',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15232796', '-36.94195936']},
#    'properties': {'schoolName': 'SCUOLA ITALIANA DI CONCEPCION',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16229248', '-36.99397215']},
#    'properties': {'schoolName': 'COLEGIO AMANECER',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16206046', '-36.97172713']},
#    'properties': {'schoolName': 'COLEGIO EINSTEIN',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.1640847', '-36.97660517']},
#    'properties': {'schoolName': 'LICEO TECNICO PROFESIONAL DE LA MADERA',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16504105', '-36.97912116']},
#    'properties': {'schoolName': 'AMERICAN JUNIOR COLLEGE',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15260038', '-36.98701096']},
#    'properties': {'schoolName': 'COLEGIO DOMINGO PARRA CORVALAN',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': ['-73.158554', '-36.985573']},
#    'properties': {'schoolName': 'LICEO BICENTENARIO DE CORONEL',
#     'community': 'CORONEL',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.03062698', '-36.92290251']},
#    'properties': {'schoolName': 'LICEO CHIGUAYANTE',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.027803', '-36.92071742']},
#    'properties': {'schoolName': 'LICEO JOSE HIPOLITO SALAS Y TORO',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02564835', '-36.91293109']},
#    'properties': {'schoolName': 'ESCUELA BASICA JOHN F. KENNEDY',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.01577997', '-36.95589048']},
#    'properties': {'schoolName': 'ESCUELA BASICA REPUBLICA DE GRECIA',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02412509', '-36.93250138']},
#    'properties': {'schoolName': 'COLEGIO PARTICULAR ANDR�S BELLO',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02948804', '-36.92276342']},
#    'properties': {'schoolName': 'COLEGIO SAN PATRICIO',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02733503', '-36.90342187']},
#    'properties': {'schoolName': 'COLEGIO CHILENO ARABE',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.0103619', '-36.93923669']},
#    'properties': {'schoolName': 'COLEGIO MADRE PAULINA',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02814289', '-36.90261371']},
#    'properties': {'schoolName': 'COLEGIO CONCEPCION CHIGUAYANTE',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02538476', '-36.92592781']},
#    'properties': {'schoolName': 'COLEGIO AURORA DE CHILE CHIGUAYANTE',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.03160933', '-36.90460914']},
#    'properties': {'schoolName': 'LICEO OBISPO SAN MIGUEL',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02740935', '-36.90876588']},
#    'properties': {'schoolName': 'COLEGIO THE PACIFIC SCHOOL',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.02166164', '-36.93294136']},
#    'properties': {'schoolName': 'COLEGIO AURORA DE CHILE SUR',
#     'community': 'CHIGUAYANTE',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.66088169', '-36.82622956']},
#    'properties': {'schoolName': 'LICEO LUIS DE ALAVA',
#     'community': 'FLORIDA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.80525061', '-36.89982266']},
#    'properties': {'schoolName': 'LICEO COPIULEMU',
#     'community': 'FLORIDA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.65340149', '-36.82314237']},
#    'properties': {'schoolName': 'LICEO INES ENRIQUEZ FRODDEN',
#     'community': 'FLORIDA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.93447921', '-36.97340482']},
#    'properties': {'schoolName': 'LICEO SAN JUAN BAUTISTA DE HUALQUI',
#     'community': 'HUALQUI',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.9293242', '-36.97127482']},
#    'properties': {'schoolName': 'ESCUELA ALONSO DE ERCILLA',
#     'community': 'HUALQUI',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15250838', '-37.095199']},
#    'properties': {'schoolName': 'LICEO POLITECNICO ROSAURO SANTANA RIOS',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.14950711', '-37.07481115']},
#    'properties': {'schoolName': 'LICEO COMERCIAL PRESIDENTE FREI MONTALVA',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16225275', '-37.08504973']},
#    'properties': {'schoolName': 'LICEO CARLOS COUSI�O GOYENECHEA',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15578491', '-37.09208791']},
#    'properties': {'schoolName': 'LICEO BALDOMERO LILLO FIGUEROA',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16145532', '-37.08480068']},
#    'properties': {'schoolName': 'ESCUELA BASICA THOMPSON MATTHEWS',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16499346', '-37.08251149']},
#    'properties': {'schoolName': 'LICEO SANTA DORIS',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.15612936', '-37.07892397']},
#    'properties': {'schoolName': 'INSTITUTO HUMANIDADES SAN FRANCISCO DE ASIS',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16159948', '-37.09083782']},
#    'properties': {'schoolName': 'COLEGIO ADVENTISTA',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.16434398', '-37.09185004']},
#    'properties': {'schoolName': 'COLEGIO PADRE MANUEL D`ALZON',
#     'community': 'LOTA',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.00047259', '-36.73866841']},
#    'properties': {'schoolName': 'LICEO PENCOPOLITANO',
#     'community': 'PENCO',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.99798938', '-36.74073322']},
#    'properties': {'schoolName': 'COLEGIO EL REFUGIO',
#     'community': 'PENCO',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.97478989', '-36.7088402']},
#    'properties': {'schoolName': 'LICEO RIOS DE CHILE',
#     'community': 'PENCO',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-72.99675597', '-36.74311864']},
#    'properties': {'schoolName': 'COLEGIO A-LAFKEN',
#     'community': 'PENCO',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.11097038', '-36.8396355']},
#    'properties': {'schoolName': 'LICEO SAN PEDRO',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.14139641', '-36.8433528']},
#    'properties': {'schoolName': 'ESCUELA BASICA  MICHAIHUE',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.12464301', '-36.86075919']},
#    'properties': {'schoolName': 'COLEGIO GALVARINO DE LOMAS COLORADAS',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.12965271', '-36.88214107']},
#    'properties': {'schoolName': 'COLEGIO PARTICULAR JUAN BOSCO',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.11419331', '-36.83232552']},
#    'properties': {'schoolName': 'ESCUELA PARTICULAR INSTITUTO  SAN PEDRO',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point',
#     'coordinates': ['-73.058757', '-36.82607453']},
#    'properties': {'schoolName': 'COLEGIO SAN IGNACIO',
#     'community': 'SAN PEDRO DE LA PAZ',
#     'province': 'CONCEPCION'}},
#   ...]}

# %%
jsonDump = json.dumps(geojson, cls=NpEncoder)
jsonOutput = json.loads(jsonDump)

# %%
with open('./data/viz/geoOutput.json', 'w') as outfile:
    json.dump(jsonOutput, outfile)
